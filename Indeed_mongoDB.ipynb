# %% [markdown]
# ### 1. Importing required libraries

# %%
from pymongo import MongoClient
import json
import pymongo

# %% [markdown]
# ### 2. Connecting to the cluster in the cloud and test the connection

# %%
# connect to MongoDB
#client = MongoClient("mongodb+srv://root:xxx@xxx-e3kq8.gcp.mongodb.net/test?retryWrites=true&w=majority")
client = MongoClient("mongodb+srv://root:root89@reemhasan-e3kq8.gcp.mongodb.net/test?retryWrites=true&w=majority")
db = client.test
db
# Out:
# Database(MongoClient(host=['reemhasan-shard-00-00-e3kq8.gcp.mongodb.net:27017', 'reemhasan-shard-00-01-e3kq8.gcp.mongodb.net:27017', 'reemhasan-shard-00-02-e3kq8.gcp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='ReemHasan-shard-0', ssl=True), 'test')

# %% [markdown]
# ### 3. Create database 'import_csv'

# %%
# create database
myDB=client['import_csv']

# %%
print(client.list_database_names())
# Out:
# ['business', 'dataia', 'import_csv', 'admin', 'local']

# %% [markdown]
# ### 4. Create a collection i.e table 'ImportCSV' inside the database 'import_csv'

# %%
# create collection 
myCollection= myDB['ImportCSV']

# %%
print(myDB.list_collection_names())
# Out:
# ['ImportCSV']

# %% [markdown]
# #### Create a compound index on the set of fields that uniquely identify a document within the  MongoDB collection.

# %%
myCollection.create_index([('User ID', pymongo.ASCENDING),('Gender', pymongo.ASCENDING),('Age',pymongo.ASCENDING)],unique=True)
# Out:
# 'User ID_1_Gender_1_Age_1'

# %%
import pandas as pd
df = pd.read_csv('Social_Network_Ads.csv',encoding = 'ISO-8859-1')   # loading csv file                              # reading json file

# %%
jsonFile=df.to_dict('records')
#jsonFile=df.to_json(orient='records')

# %%
jsonFile
# Out:
# [{'User ID': 15624510,
#   'Gender': 'Male',
#   'Age': 19,
#   'EstimatedSalary': 19000,
#   'Purchased': 0},
#  {'User ID': 15810944,
#   'Gender': 'Male',
#   'Age': 35,
#   'EstimatedSalary': 20000,
#   'Purchased': 0},
#  {'User ID': 15668575,
#   'Gender': 'Female',
#   'Age': 26,
#   'EstimatedSalary': 43000,
#   'Purchased': 0},
#  {'User ID': 15603246,
#   'Gender': 'Female',
#   'Age': 27,
#   'EstimatedSalary': 57000,
#   'Purchased': 0},
#  {'User ID': 15804002,
#   'Gender': 'Male',
#   'Age': 19,
#   'EstimatedSalary': 76000,
#   'Purchased': 0},
#  {'User ID': 15728773,
#   'Gender': 'Male',
#   'Age': 27,
#   'EstimatedSalary': 58000,
#   'Purchased': 0},
#  {'User ID': 15598044,
#   'Gender': 'Female',
#   'Age': 27,
#   'EstimatedSalary': 84000,
#   'Purchased': 0},
#  {'User ID': 15694829,
#   'Gender': 'Female',
#   'Age': 32,
#   'EstimatedSalary': 150000,
#   'Purchased': 1},
#  {'User ID': 15600575,
#   'Gender': 'Male',
#   'Age': 25,
# ...

# %%
# mongoDB do'nt accept point in the key which is a field name, so it must be deleted 
myCollection.insert_many(jsonFile)

# %% [markdown]
# ### 5. Select just the two first rows

# %%
myresult = myCollection.find().limit(2)

# %%
for doc in myresult:
    print(doc)
    #print('\n\n')
# Out:
# {'_id': ObjectId('5ec29788c21ff95e7dd21cdc'), 'User ID': 15624510, 'Gender': 'Male', 'Age': 19, 'EstimatedSalary': 19000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21cdd'), 'User ID': 15810944, 'Gender': 'Male', 'Age': 35, 'EstimatedSalary': 20000, 'Purchased': 0}

# %% [markdown]
# ####  Show the total number of inserted rows

# %%
myCollection.count_documents({})
# Out:
# 400

# %% [markdown]
# ### 6. Searching for a specific document

# %%
#Game Of Thrones S02E01 The North Remembers.12: "Here I am."
cursor=myCollection.find({"Gender": "Male"})
for doc in cursor:
    print(doc)
# Out:
# {'_id': ObjectId('5ec29788c21ff95e7dd21cdc'), 'User ID': 15624510, 'Gender': 'Male', 'Age': 19, 'EstimatedSalary': 19000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21cdd'), 'User ID': 15810944, 'Gender': 'Male', 'Age': 35, 'EstimatedSalary': 20000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21ce0'), 'User ID': 15804002, 'Gender': 'Male', 'Age': 19, 'EstimatedSalary': 76000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21ce1'), 'User ID': 15728773, 'Gender': 'Male', 'Age': 27, 'EstimatedSalary': 58000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21ce4'), 'User ID': 15600575, 'Gender': 'Male', 'Age': 25, 'EstimatedSalary': 33000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21ce8'), 'User ID': 15746139, 'Gender': 'Male', 'Age': 20, 'EstimatedSalary': 86000, 'Purchased': 0}
# {'_id': ObjectId('5ec29788c21ff95e7dd21ce9'), 'User ID': 15704987, 'Gender': 'Male', 'Age': 32, 'EstimatedSalary': 18000, 'Purchased': 0}
# ...

# %% [markdown]
# ### Avoid adding the same document (row) in MongoDB

# %% [markdown]
# ###### Try to add the same 100 documents into the table ImportCSV

# %%
DuplicatedjsonFile=jsonFile[0:100]
len(DuplicatedjsonFile)
# Out:
# 100

# %%
myCollection.insert_many(DuplicatedjsonFile)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-73-ce94e2f7fcc5> in <module>
# ----> 1 myCollection.insert_many(DuplicatedjsonFile)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
#     757         blk.ops = [doc for doc in gen()]
# --> 758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     760
#
# ~\Anaconda3\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     509                 self.execute_no_results(sock_info, generator)
#     510         else:
# --> 511             return self.execute_command(generator, write_concern, session)
#     512
#     513
#
# ...

# %% [markdown]
# Can not add the same rows to the tabe ImportCSV, because of the index we created

# %% [markdown]
# ###  Delete all the documents (rows) in the collection

# %%
# query = myCollection.delete_many({})

# %% [markdown]
# ###  Delete the collection

# %%
#myCollection.drop()
